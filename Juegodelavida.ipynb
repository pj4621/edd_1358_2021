# %% [markdown]
# <a href="https://colab.research.google.com/github/pj4621/edd_1358_2021/blob/master/Juegodelavida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Array2D:
    def __init__(self,fil,col):
        self.renglon = fil
        self.columna = col
        self.array=[[0 for i in range(col)] for i in range(fil)]
      
    def get_row_size(self):
        return self.renglon
        
    def get_col_size(self):
        return self.columna
            
    def get_item(self,fil,col):
        return self.array[fil][col]
        
    def set_item( self , fil , col , valor ):
        self.array[fil][col]=valor
           
    def to_string(self):
        return self.array
            
class JuegoDeLaVida:
    def __init__( self,fil,col,gen,confi_genera):
        self.columna = col
        self.fila = fil
        self.grid = Array2D(self.fila,self.columna)
        self.gen = gen
        
        for i in confi_genera:
            self.grid.set_item(i[0],i[1],1)
        
        
    def imprime_grid( self ):
        for r in range(self.grid.get_col_size()):
            for c in range(self.grid.get_row_size()):
                if self.grid.get_item(r,c) == 0:
                    print("░░",end="")
                else:
                    print("▓▓",end="")
            print("")
        print("")

    
    def get_num_rows(self):	
        return self.alto
    
    def get_num_col(self):
        return self.columna
    
    def set_celula_muerta(self,row,col):
        self.grid.set_item(row,col,0)
    
    def set_celula_viva(self,row,col):
        self.grid.set_item(row,col,1)
        
    def get_celula_viva(self,row,col):
        return self.grid.get_item(row,col) == 1
    
    def get_celula_muerta(self,row,col):
        return self.grid.get_item(row,col) == 0

    def get_vecinos_vivos(self, row ,col):
        contador = 0
        for i in [row-1,row,row+1]:
            for j in [col-1,col,col+1]:
                try:
                    if self.grid.get_item(i,j)==1 and (i,j) !=(row,col):
                        contador +=1
                except Exception as ex:
                    pass
        return contador
    
    def generacion ( self ):
        for i in range( self.gen):
            array = self.grid.to_string()
            self.imprime_grid()
            vivos = []
            muertos = []

            for row in range( self.fila):
                for col in range( self.columna ):
                    if self.get_vecinos_vivos( row, col)==3:
                        vivos.append((row,col))

                    if self.get_vecinos_vivos( row , col )==2:
                        pass

                    if self.get_vecinos_vivos( row , col )< 2 or self.get_vecinos_vivos(row,col)>3:
                        muertos.append((row,col))
            
            for i in vivos:
                self.set_celula_viva(i[0],i[1])

            for i in muertos:
                self.set_celula_muerta(i[0],i[1])
            
print("Coordenadas de la primera generacion : [(1,2), (2,1), (2,2), (2,3)]")
print("")


array = JuegoDeLaVida(f,c,g,[(1,2),(2,1),(2,2),(2,3)])
array.generacion()
        
print("Fin del programa")
# Out:
# Coordenadas de la primera generacion : [(1,2), (2,1), (2,2), (2,3)]
#
# ░░░░░░░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ▓▓░░░░░░▓▓░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ▓▓▓▓░░▓▓▓▓░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# Fin del programa
